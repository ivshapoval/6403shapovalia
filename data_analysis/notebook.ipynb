# %%
from datetime import datetime
from timerow.module.functions import WeatherData
from meteostat import Point, Daily
import pandas as pd

# %%
# Получение данных через meteostat

start = datetime(2020, 1, 1)
end = datetime(2024, 11, 7)

# Точка для измерения погоды - Самара
samara = Point(53.2001, 50.15, 116)

# Получение данных о погоде в Самаре
data = Daily(samara, start, end)
data = data.fetch()

# %%
# Инициализация модуля для расчета данных о погоде

weather = WeatherData(data)
weather.get_data()
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2020-01-01  -2.5  -3.4  -1.8   NaN   NaN  223.0   6.6   NaN   998.6   NaN
# 2020-01-02  -5.6  -8.4  -1.4   NaN   NaN  282.0  11.4   NaN  1011.1   NaN
# 2020-01-03  -6.1  -8.4  -1.4   NaN   NaN  206.0  13.2   NaN  1016.7   NaN
# 2020-01-04  -2.0  -3.4  -1.3   NaN   NaN  230.0  21.8   NaN  1010.7   NaN
# 2020-01-05  -0.3  -1.8   0.6   NaN   NaN  225.0  16.2   NaN  1012.0   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-11-03  -1.0  -2.4   0.6   0.0   NaN  268.0  18.0   NaN  1004.8   NaN
# 2024-11-04  -1.1  -2.4   0.6   1.3   NaN  203.0  11.2   NaN  1007.6   NaN
# 2024-11-05  -2.2  -3.4  -1.4   3.4   NaN   35.0  19.0   NaN  1004.5   NaN
# 2024-11-06  -4.1  -6.4  -2.4   0.0   NaN  320.0  20.7   NaN  1010.6   NaN
# 2024-11-07  -2.8  -3.7  -1.7   1.8   NaN  258.0   5.6   NaN  1017.4   NaN
#
# [1773 rows x 10 columns]

# %%
# Вычисление скользящего среднего 
weather.moving_average(21)
# Вычисление разницы между значениями скользящего среднего
weather.calculate_difference(21)

# %%
# Поиск экстремальных значений скользящего среднего
weather.find_extremal(21)
# Out:
# time
# 2020-01-01         NaN
# 2020-01-02         NaN
# 2020-01-03         NaN
# 2020-01-04         NaN
# 2020-01-05         NaN
#                 ...
# 2024-11-03    4.347619
# 2024-11-04    4.238095
# 2024-11-05    3.995238
# 2024-11-06    3.595238
# 2024-11-07    3.238095
# Name: moving_average_21, Length: 1769, dtype: float64

# %%
# Поиск экстремальных значений скользящего среднего
weather.autocorrelation(21)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 2020-01-01  -2.5  -3.4  -1.8   NaN   NaN  223.0   6.6   NaN   998.6   NaN
# 2020-01-02  -5.6  -8.4  -1.4   NaN   NaN  282.0  11.4   NaN  1011.1   NaN
# 2020-01-03  -6.1  -8.4  -1.4   NaN   NaN  206.0  13.2   NaN  1016.7   NaN
# 2020-01-04  -2.0  -3.4  -1.3   NaN   NaN  230.0  21.8   NaN  1010.7   NaN
# 2020-01-05  -0.3  -1.8   0.6   NaN   NaN  225.0  16.2   NaN  1012.0   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-11-03  -1.0  -2.4   0.6   0.0   NaN  268.0  18.0   NaN  1004.8   NaN
# 2024-11-04  -1.1  -2.4   0.6   1.3   NaN  203.0  11.2   NaN  1007.6   NaN
# 2024-11-05  -2.2  -3.4  -1.4   3.4   NaN   35.0  19.0   NaN  1004.5   NaN
# 2024-11-06  -4.1  -6.4  -2.4   0.0   NaN  320.0  20.7   NaN  1010.6   NaN
# 2024-11-07  -2.8  -3.7  -1.7   1.8   NaN  258.0   5.6   NaN  1017.4   NaN
#
#             moving_average_21  temperature_difference  extremal     autoc
# ...

# %%
# Сохранение данных в results.xlsx
print(data)
if data is not None:
    data.to_excel("results.xlsx")
    print(f"Данные успешно сохранены в results.xlsx")
else:
    print("Нет данных для сохранения.")
# Out:
# ...
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 2020-01-01  -2.5  -3.4  -1.8   NaN   NaN  223.0   6.6   NaN   998.6   NaN
# 2020-01-02  -5.6  -8.4  -1.4   NaN   NaN  282.0  11.4   NaN  1011.1   NaN
# 2020-01-03  -6.1  -8.4  -1.4   NaN   NaN  206.0  13.2   NaN  1016.7   NaN
# 2020-01-04  -2.0  -3.4  -1.3   NaN   NaN  230.0  21.8   NaN  1010.7   NaN
# 2020-01-05  -0.3  -1.8   0.6   NaN   NaN  225.0  16.2   NaN  1012.0   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-11-03  -1.0  -2.4   0.6   0.0   NaN  268.0  18.0   NaN  1004.8   NaN
# 2024-11-04  -1.1  -2.4   0.6   1.3   NaN  203.0  11.2   NaN  1007.6   NaN
# 2024-11-05  -2.2  -3.4  -1.4   3.4   NaN   35.0  19.0   NaN  1004.5   NaN
# 2024-11-06  -4.1  -6.4  -2.4   0.0   NaN  320.0  20.7   NaN  1010.6   NaN
# 2024-11-07  -2.8  -3.7  -1.7   1.8   NaN  258.0   5.6   NaN  1017.4   NaN
#
#             moving_average_21  temperature_difference  extremal     autoc
# ...
